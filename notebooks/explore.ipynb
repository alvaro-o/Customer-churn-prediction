# %%
import pandas as pd
from pathlib import Path

# %% [markdown]
# ### Withdrawals

# %%
# Data Read
data_path = Path("../data")
df_withdrawals = pd.read_parquet(data_path / "zrive_advertiser_withdrawals.parquet")

# %%
CHURN_REASONS_EXCLUDED = [
    'Upselling-cambio de contrato',
    'Cambio a Bundle Online',
    'Cambio de Contrato/propuesta/producto'
]

df_withdrawals["churn"] = (
    (df_withdrawals["withdrawal_type"] == "TOTAL") &
    (df_withdrawals["withdrawal_status"] != "Denegada") &
    (~df_withdrawals["withdrawal_reason"].isin(CHURN_REASONS_EXCLUDED))
).astype(int)

# %%
df_withdrawals
# Out:
#        withdrawal_id  advertiser_zrive_id withdrawal_status withdrawal_type  \
# 0                  0                  257           Cerrada           TOTAL
# 1                  1                  219           Cerrada           TOTAL
# 2                  7                  487           Cerrada           TOTAL
# 3                 12                  476           Cerrada           TOTAL
# 4                 16                  452           Cerrada           TOTAL
# ...              ...                  ...               ...             ...
# 20674          53126                 5441           Cerrada           TOTAL
# 20675          53127                 5439           Cerrada           TOTAL
# 20676          53128                  154           Cerrada           TOTAL
# 20677          53129                 1352           Cerrada           TOTAL
# 20678          53130                 4153           Cerrada           TOTAL
#
#       withdrawal_creation_date    withdrawal_reason  churn
# 0          2012-06-19 07:12:34           RESULTADOS      1
# 1          2012-06-19 07:16:34           RESULTADOS      1
# 2          2012-06-20 07:10:16           RESULTADOS      1
# 3          2012-06-20 11:59:36           RESULTADOS      1
# 4          2012-06-20 15:41:39  FALTA DE USO/TIEMPO      1
# ...                        ...                  ...    ...
# 20674      2024-12-30 21:46:47  FALTA DE USO/TIEMPO      1
# 20675      2024-12-30 21:47:47  FALTA DE USO/TIEMPO      1
# 20676      2024-12-30 22:08:19   RAZONES ECONOMICAS      1
# 20677      2024-12-30 22:13:53   RAZONES ECONOMICAS      1
# 20678      2024-12-30 22:16:01  FALTA DE USO/TIEMPO      1
#
# [20679 rows x 7 columns]

# %% [markdown]
# Data to be used for defining churn (joining by advertiser and defining the withdrawal date)

# %% [markdown]
# ### Advertisers

# %%
data_path = Path("../data")
df_advertiser = pd.read_parquet(data_path / "zrive_dim_advertiser.parquet")

# %%
df_advertiser.head(20)
# Out:
#     advertiser_zrive_id  province_id          updated_at advertiser_province  \
# 0                  6732            1 2025-02-05 01:02:08               Álava
# 1                  4841            2 2024-08-09 13:38:43            Albacete
# 2                  2487            3 2025-01-13 17:41:02            Alicante
# 3                  1771            3 2024-11-07 13:26:50            Alicante
# 4                  3396            3 2023-11-02 13:51:07            Alicante
# 5                  3008            3 2024-04-25 14:37:44            Alicante
# 6                  4836            3 2024-08-09 13:40:33            Alicante
# 7                  4972            3 2024-12-04 11:55:31            Alicante
# 8                   542            3 2024-02-05 13:49:02            Alicante
# 9                  4595            3 2023-03-07 01:13:14            Alicante
# 10                 3004            5 2023-12-02 01:08:05            Asturias
# 11                 3356            5 2022-10-28 13:28:56            Asturias
# 12                 5019            5 2024-05-28 12:02:26            Asturias
# 13                 3376            7 2024-11-07 11:20:24             Badajoz
# 14                 1280            8 2024-07-05 11:30:50           Barcelona
# 15                  529            8 2024-07-05 11:33:04           Barcelona
# 16                 4993            8 2023-11-02 13:52:14           Barcelona
# 17                 2399            8 2024-08-09 09:48:54           Barcelona
# 18                 3916            8 2025-02-23 01:00:15           Barcelona
# 19                 4922            8 2023-06-20 01:07:04           Barcelona
#
#     advertiser_group_id min_start_contrato_date max_start_contrato_nuevo_date  \
# 0                   NaN              2025-01-24                          None
# 1                 133.0              2023-02-24                          None
# 2                   NaN              2024-10-02                    2024-10-02
# 3                 185.0              2021-11-15                          None
# 4                   NaN              2023-03-17                    2023-03-17
# 5                   NaN              2024-02-02                          None
# 6                 133.0              2023-02-24                          None
# 7                   NaN              2023-04-03                          None
# 8                   NaN              2023-05-03                          None
# 9                   NaN              2022-12-19                          None
# 10                  NaN              2020-12-01                    2020-12-01
# 11                  NaN              2024-03-11                          None
# 12                156.0              2023-05-16                    2023-05-16
# 13                  NaN              2022-02-03                          None
# 14                 41.0              2024-04-29                          None
# 15                 41.0              2024-04-30                          None
# 16                  NaN              2023-04-13                    2023-04-13
# 17                 41.0              2022-07-19                    2022-07-19
# 18                  NaN              2023-06-21                    2024-02-09
# 19                  NaN              2023-03-21                    2023-03-21
#
#    contrato_churn_date
# 0           2025-02-04
# 1           2023-06-03
# 2           2025-01-13
# 3           2024-11-06
# 4           2023-11-01
# 5           2024-04-09
# 6           2023-06-03
# 7           2023-07-02
# 8           2023-12-29
# 9           2023-03-06
# 10          2023-12-01
# 11          2024-03-15
# 12          2023-12-19
# 13          2024-11-01
# 14          2024-08-03
# 15          2024-06-29
# 16          2023-11-01
# 17          2024-06-28
# 18          2025-02-20
# 19          2023-06-14

# %% [markdown]
# - Initially ignore the region (study then after a first iteration if it adds value)
# - Add a boolean specifying if it's new or comes back
# - Advertiser group id to convert to boolean column
# - Feature engineer could be like % of time till contract expiry

# %% [markdown]
# ### Monthly

# %%
data_path = Path("../data")
df_monthly = pd.read_parquet(data_path / "zrive_fct_monthly_snapshot_advertiser.parquet")

# %%
df_monthly
# Out:
#        advertiser_zrive_id  period_int  monthly_published_ads  \
# 0                        1      202301                     47
# 1                        2      202301                     31
# 2                        3      202301                      0
# 3                        4      202301                     79
# 4                        6      202301                     20
# ...                    ...         ...                    ...
# 80122                 6800      202412                      7
# 80123                 6808      202412                     17
# 80124                 6822      202412                     18
# 80125                 6823      202412                     10
# 80126                 6824      202412                      6
#
#        monthly_unique_published_ads  monthly_contracted_ads  monthly_leads  \
# 0                                47                      75             18
# 1                                31                     150              4
# 2                                 0                       0              0
# 3                                79                      85             14
# 4                                20                      20             16
# ...                             ...                     ...            ...
# 80122                             7                      10              0
# 80123                            17                      20              3
# 80124                            18                      35             60
# 80125                            10                      10              4
# 80126                             6                      10              0
#
#        monthly_visits  monthly_oro_ads  monthly_plata_ads  \
# 0             40890.0                6                  6
# 1             17970.0               10                 10
# 2                 0.0                0                  0
# 3             27157.5                3                  3
# 4             79492.5                0                  0
# ...               ...              ...                ...
# 80122          2857.5                1                  1
# 80123         12967.5                0                  0
# 80124         74362.5                5                  6
# 80125         23857.5                0                  0
# 80126          1515.0                0                  0
#
#        monthly_destacados_ads  ...  monthly_total_phone_views  \
# 0                           6  ...                         14
# 1                           4  ...                         16
# 2                           0  ...                          0
# 3                           1  ...                         10
# 4                           1  ...                         10
# ...                       ...  ...                        ...
# 80122                       4  ...                          0
# 80123                       0  ...                          3
# 80124                      15  ...                         21
# 80125                       1  ...                          1
# 80126                       0  ...                          1
#
#        monthly_total_calls  monthly_total_emails  monthly_total_invoice  \
# 0                       15                     0                  440.8
# 1                        2                     2                   75.4
# 2                        0                     0                    0.0
# 3                        8                     2                  299.6
# 4                        4                     3                   86.5
# ...                    ...                   ...                    ...
# 80122                    0                     0                    0.0
# 80123                    2                     0                    0.0
# 80124                   31                     7                    0.0
# 80125                    1                     0                    0.0
# 80126                    0                     0                    0.0
#
#        monthly_unique_calls  monthly_unique_emails  monthly_unique_leads  \
# 0                        12                      3                    15
# 1                         2                      2                     4
# 2                         0                      0                     0
# 3                         6                      6                    12
# 4                         4                     11                    15
# ...                     ...                    ...                   ...
# 80122                     0                      0                     0
# 80123                     2                      1                     3
# 80124                    26                     26                    52
# 80125                     1                      3                     4
# 80126                     0                      0                     0
#
#        monthly_avg_ad_price  monthly_distinct_ads  has_active_contract
# 0                       NaN                   NaN                 True
# 1                       NaN                   NaN                 True
# 2                       NaN                   NaN                False
# 3                       NaN                   NaN                 True
# 4                       NaN                   NaN                 True
# ...                     ...                   ...                  ...
# 80122               8840.00                   8.0                False
# 80123              36487.70                  28.0                False
# 80124               7595.83                  48.0                False
# 80125              49590.00                  15.0                False
# 80126              33695.00                   6.0                False
#
# [80127 rows x 22 columns]

# %%
df_monthly.columns
# Out:
# Index(['advertiser_zrive_id', 'period_int', 'monthly_published_ads',
#        'monthly_unique_published_ads', 'monthly_contracted_ads',
#        'monthly_leads', 'monthly_visits', 'monthly_oro_ads',
#        'monthly_plata_ads', 'monthly_destacados_ads', 'monthly_pepitas_ads',
#        'monthly_shows', 'monthly_total_phone_views', 'monthly_total_calls',
#        'monthly_total_emails', 'monthly_total_invoice', 'monthly_unique_calls',
#        'monthly_unique_emails', 'monthly_unique_leads', 'monthly_avg_ad_price',
#        'monthly_distinct_ads', 'has_active_contract'],
#       dtype='object')

# %% [markdown]
# ### Feature Engineering

# %% [markdown]
# Use monthly as a basis... So let's clean and join into that dataframe

# %%
df_withdrawals_ = df_withdrawals[["advertiser_zrive_id", "withdrawal_creation_date", "churn"]]

# %%
df_withdrawals_
# Out:
#        advertiser_zrive_id withdrawal_creation_date  churn
# 0                      257      2012-06-19 07:12:34      1
# 1                      219      2012-06-19 07:16:34      1
# 2                      487      2012-06-20 07:10:16      1
# 3                      476      2012-06-20 11:59:36      1
# 4                      452      2012-06-20 15:41:39      1
# ...                    ...                      ...    ...
# 20674                 5441      2024-12-30 21:46:47      1
# 20675                 5439      2024-12-30 21:47:47      1
# 20676                  154      2024-12-30 22:08:19      1
# 20677                 1352      2024-12-30 22:13:53      1
# 20678                 4153      2024-12-30 22:16:01      1
#
# [20679 rows x 3 columns]

# %%
df_advertiser['advertiser_group'] = df_advertiser['advertiser_group_id'].notna()
df_advertiser['customer_before'] = df_advertiser['max_start_contrato_nuevo_date'].notna()

# %%
df_advertiser['updated_at'] = pd.to_datetime(df_advertiser['updated_at'], errors='coerce')
df_advertiser['min_start_contrato_date'] = pd.to_datetime(df_advertiser['min_start_contrato_date'], errors='coerce')
df_advertiser['contrato_churn_date'] = pd.to_datetime(df_advertiser['contrato_churn_date'], errors='coerce')

# %%
df_advertiser['contrato_percentage'] = 100 * (df_advertiser['updated_at'] - df_advertiser['min_start_contrato_date']).dt.days / (df_advertiser['contrato_churn_date'] - df_advertiser['min_start_contrato_date']).dt.days
df_advertiser['months_active'] = (
    (df_advertiser['updated_at'].dt.year - df_advertiser['min_start_contrato_date'].dt.year) * 12 +
    (df_advertiser['updated_at'].dt.month - df_advertiser['min_start_contrato_date'].dt.month)
)

# %%
df_advertiser
# Out:
#       advertiser_zrive_id  province_id          updated_at  \
# 0                    6732            1 2025-02-05 01:02:08
# 1                    4841            2 2024-08-09 13:38:43
# 2                    2487            3 2025-01-13 17:41:02
# 3                    1771            3 2024-11-07 13:26:50
# 4                    3396            3 2023-11-02 13:51:07
# ...                   ...          ...                 ...
# 6829                 6079           46 2025-02-19 14:13:04
# 6830                 4775           47 2025-03-10 13:32:11
# 6831                 4712           48 2024-06-27 18:05:17
# 6832                 5686           50 2025-03-17 17:29:04
# 6833                 3586           50 2024-07-30 11:17:46
#
#      advertiser_province  advertiser_group_id min_start_contrato_date  \
# 0                  Álava                  NaN              2025-01-24
# 1               Albacete                133.0              2023-02-24
# 2               Alicante                  NaN              2024-10-02
# 3               Alicante                185.0              2021-11-15
# 4               Alicante                  NaN              2023-03-17
# ...                  ...                  ...                     ...
# 6829            Valencia                  NaN              2024-11-19
# 6830          Valladolid                  NaN              2024-12-12
# 6831             Vizcaya                 41.0              2023-01-30
# 6832            Zaragoza                  NaN              2024-02-07
# 6833            Zaragoza                  NaN              2024-06-28
#
#      max_start_contrato_nuevo_date contrato_churn_date  advertiser_group  \
# 0                             None          2025-02-04             False
# 1                             None          2023-06-03              True
# 2                       2024-10-02          2025-01-13             False
# 3                             None          2024-11-06              True
# 4                       2023-03-17          2023-11-01             False
# ...                            ...                 ...               ...
# 6829                    2024-11-19          2025-03-31             False
# 6830                    2024-12-12          2025-03-31             False
# 6831                    2023-01-30          2025-03-31              True
# 6832                    2024-02-07          2025-03-31             False
# 6833                    2024-06-28          2025-03-31             False
#
#       customer_before  contrato_percentage  months_active
# 0               False           109.090909              1
# 1               False           537.373737             18
# 2                True           100.000000              3
# 3               False           100.091996             36
# 4                True           100.436681              8
# ...               ...                  ...            ...
# 6829             True            69.696970              3
# 6830             True            80.733945              3
# 6831             True            64.981037             17
# 6832             True            96.650718             13
# 6833             True            11.594203              1
#
# [6834 rows x 12 columns]

# %% [markdown]
# There seems to be some contracts which are not updated...

# %%
df_advertiser_ = df_advertiser.drop(columns=["province_id", "advertiser_province", "advertiser_group_id", "min_start_contrato_date", "max_start_contrato_nuevo_date", "contrato_churn_date"])

# %%
df_advertiser_
# Out:
#       advertiser_zrive_id          updated_at  advertiser_group  \
# 0                    6732 2025-02-05 01:02:08             False
# 1                    4841 2024-08-09 13:38:43              True
# 2                    2487 2025-01-13 17:41:02             False
# 3                    1771 2024-11-07 13:26:50              True
# 4                    3396 2023-11-02 13:51:07             False
# ...                   ...                 ...               ...
# 6829                 6079 2025-02-19 14:13:04             False
# 6830                 4775 2025-03-10 13:32:11             False
# 6831                 4712 2024-06-27 18:05:17              True
# 6832                 5686 2025-03-17 17:29:04             False
# 6833                 3586 2024-07-30 11:17:46             False
#
#       customer_before  contrato_percentage  months_active
# 0               False           109.090909              1
# 1               False           537.373737             18
# 2                True           100.000000              3
# 3               False           100.091996             36
# 4                True           100.436681              8
# ...               ...                  ...            ...
# 6829             True            69.696970              3
# 6830             True            80.733945              3
# 6831             True            64.981037             17
# 6832             True            96.650718             13
# 6833             True            11.594203              1
#
# [6834 rows x 6 columns]
